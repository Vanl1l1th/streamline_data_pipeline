# %% [markdown]
# # Image feature extraction

# %%
import numpy as np
from sklearn.feature_extraction import image
from sklearn.decomposition import PCA
from skimage.io import imread
import matplotlib.pyplot as plt

path_list = []
for i in range(8):
    path = "img_data/img" + str(i+1) + ".jpg"
    path_list.append(path)

print(path_list)

def split_patches(path_list):
    patches_list = []
    for path in path_list:
        img = imread(path, as_gray=True)
        patches = image.extract_patches_2d(img,(20,20))
        num_patches = patches.shape[0]
        flat_patches = patches.reshape(num_patches,-1)
        patches_list.append(flat_patches)
    return patches_list

def pca_reduction(patches_list):
    pca = PCA(n_components=2)
    reduced_patches_list = []
    for p in patches_list:
        reduced_p = pca.fit_transform(p)
        reduced_patches_list.append(reduced_p)
    return reduced_patches_list

def plot_vis(plot_list): #takes a list of data sets to visualize in a scatter plot. Each entry should have format of list of arrays with each array n*2
    num_plot = len(plot_list)
    cols = 3
    rows = num_plot % cols
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 3))
    axes = axes.flatten()  # Flatten the 2D array of axes for easier indexing

    for i, plot in enumerate(plot_list):
        x = plot[:, 0]
        y = plot[:, 1]
        ax = axes[i]
        ax.scatter(x, y, s=1, alpha=0.5)  # Use scatter plot for large datasets
        ax.set_title("img" + str(i+1))
        ax.grid(True)
         
    plt.tight_layout()
    plt.show()

# %%
patches = split_patches(path_list)
reduced_patches = pca_reduction(patches)
for p in reduced_patches:
    print(p.shape)
    
plot_vis(reduced_patches)
# Out:
# (42074, 2)
# (41869, 2)

# %%
b = imread("img_data/img02.jpg", as_gray=True)

patches = image.extract_patches_2d(b,(100,100))
print(patches.shape)

num_patches = patches.shape[0]
reshaped_patches = patches.reshape(num_patches, -1)  # Flatten each patch
print(reshaped_patches.shape)

pca = PCA(n_components=2)
pca.fit(reshaped_patches)

transformed_patches = pca.transform(reshaped_patches)
print(transformed_patches.shape)

#plot visualisation
x = transformed_patches[:,0]
y = transformed_patches[:,1]

plt.figure(figsize=(10, 6))
plt.scatter(x, y, s=1, alpha=0.5)  # Use scatter plot for large datasets
plt.grid(True)
plt.show()
# Out:
# (13869, 100, 100)
# (13869, 10000)
# (13869, 2)
